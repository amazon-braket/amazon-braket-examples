# %% [markdown]
# # Using the CUDA-Q Applications Hub

# %% [markdown]
# Welcome! This notebook provides a quick and easy way to pull the NVIDIA CUDA-Q Applications Hub directly into your Amazon Braket environment.
#
# Designed for researchers and developers, these notebooks feature industry-driven use cases that demonstrate CUDA-Q's ability to seamlessly integrate GPU acceleration with quantum processors and scale complex hybrid algorithms.
#
# You can browse these examples in the [CUDA-Q Applications Hub](https://nvidia.github.io/cuda-quantum/latest/using/applications.html).

# %% [markdown]
# ### Ensure latest CUDA-Q packages are installed

# %% [markdown]
# Run the following cell to ensure that your environment has the latest versions of the CUDA-Q packages in order to be compatible with the CUDA-Q Applications Hub:

# %%
# %pip install --upgrade cudaq cudaq-qec cudaq-solvers

# %% [markdown]
# Now let's print the installed CUDA-Q package versions for reference:

# %%
# %pip freeze | grep cudaq

# %% [markdown]
# ### Clone the CUDA-Q Applications Hub

# %% [markdown]
# The command below will clone the CUDA-Q Applications Hub notebooks into a local folder called `cuda-q-applications` so that you can explore and run them directly within this notebook environment. (If the folder already exists locally, it will be moved to a backup folder.)
#
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> Running the cell below will download content that is provided by NVIDIA. While most things should work, some notebooks may not be fully functional within an Amazon Braket notebook instance. If you encounter any problems while running the notebooks, please <a href="https://github.com/NVIDIA/cuda-quantum/issues">open an issue in the CUDA-Q Applications Hub repo on GitHub</a>.
# </div>
#
# Run this cell to clone the CUDA-Q Applications Hub:

# %%
![ -d cuda-q-applications ] && mv cuda-q-applications cuda-q-applications-backup-$(date +%Y%m%d-%H%M%S); git clone --filter=blob:none --sparse --depth 1 https://github.com/NVIDIA/cuda-quantum.git cuda-q-applications && cd cuda-q-applications && COMMIT_HASH=$(git rev-parse HEAD) && COMMIT_URL="https://github.com/NVIDIA/cuda-quantum/tree/$COMMIT_HASH/docs/sphinx/applications/python" && git sparse-checkout set docs/sphinx/applications/python && rm -rf .git && cd .. && mv cuda-q-applications cuda-q-applications-temp && mv cuda-q-applications-temp/docs/sphinx/applications/python cuda-q-applications && rm -rf cuda-q-applications-temp && echo "" && echo "✅ Success! The CUDA-Q Applications Hub has been cloned to the \`cuda-q-applications\` folder" && echo "   Synced from commit: $COMMIT_HASH" && echo "   View at commit: $COMMIT_URL"

# %% [markdown]
# You can now navigate into the `cuda-q-applications` folder to explore the library.
