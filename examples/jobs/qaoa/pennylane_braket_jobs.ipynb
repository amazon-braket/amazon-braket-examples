# %% [markdown]
# # QAOA with Amazon Braket Hybrid Jobs and PennyLane
#
# In this tutorial, we use Pennylane withing Amazon Braket Hybrid Jobs to run the Quantum Approximate Optimization Algorithm (QAOA) on a Max-Cut problem.
#
# ## Learning outcomes
# * Use pre-built Pennylane containers in Braket Jobs
# * Set QAOA hyperparameters
# * Choose Pennylane backend (TensorFlow, PyTorch)
# * Use checkpoints for Braket Jobs

# %% [markdown]
# ## QAOA background
#
# QAOA is a variational algorithm with input parameters to a quantum circuit that evaluates a classical cost function; these parameters are optimized to minimize the cost function. In running QAOA, it's common to adjust the hyperparameters such as circuit depth ($p$). Braket Jobs helps organize experiments and results. In the following, we show how to setup the problem, prepare input data and run QAOA using Braket Jobs.
#
# For more information about QAOA and PennyLane, see [this example notebook](../pennylane/2_Graph_optimization_with_QAOA.ipynb) or [this PennyLane tutorial](https://pennylane.ai/qml/demos/tutorial_qaoa_intro.html).

# %% [markdown]
# ## Problem setup
#
# We first create and visualize a random graph for the Max-Cut problem with <code>networkx</code> package. Feel free to play with the number of nodes, <code>n</code>, and number of edges, <code>m</code>.

# %%
import time

import networkx as nx
from braket.aws import AwsQuantumJob, AwsSession
from braket.jobs.image_uris import Framework, retrieve_image

# %%
# We generate a random graph with num_nodes nodes and num_edges edges to run Max Cut on.
# num_nodes is the number of qubits, so each circuit will have runtime exponential in num_nodes
num_nodes = 6
num_edges = 8
seed = 1967

graph = nx.gnm_random_graph(num_nodes, num_edges, seed=seed)

# Draw the graph
positions = nx.spring_layout(graph, seed=seed)
nx.draw(graph, with_labels=True, pos=positions, node_size=600)

# %% [markdown]
# ## Prepare input data
# We also need to prepare the input data for training. The input data can be specified by either a path to a local file, or an Amazon S3 path that points to the data. In this notebook, the input data is the random graph we created. We simply create a file in the local directory encoding the input graph.

# %%
input_file_path = "input-data.adjlist"
nx.write_adjlist(graph, input_file_path)

# %% [markdown]
# ## Specify hyperparameters and configurations
#
# The hyperparameters can be forwarded to the algorithm script through the keyword argument <code>hyperparameters</code>. It usually includes, but not limited to, the variables that are required to define a training procedure, such as the number of iterations, or to set up an optimizer, such as the learning rate. Here, we pack these hyperparameters into a dictionary which will later become the input of the algorithm script. <code>device</code> has a dedicated input channel, so we do not include it in the hyperparameters.

# %%
# Pick 'autograd', 'tf', or 'torch'. Autograd is base PennyLane
interface = "autograd"
# Specify device that the job will primarily be targeting
device = "arn:aws:braket:::device/quantum-simulator/amazon/sv1"

hyperparameters = {
    # Number of tasks per iteration = 2 * (num_nodes + num_edges) * p + 1
    "p": "2",
    "seed": str(seed),
    # Maximum number of simultaneous tasks allowed
    "max_parallel": "10",
    # Number of total optimization iterations, including those from previous checkpoint (if any)
    "num_iterations": "5",
    # Step size / learning rate for gradient descent
    "stepsize": "0.1",
    # Shots for each circuit execution
    "shots": "1000",
    "interface": interface,
}

# %% [markdown]
# Braket Jobs has three pre-built containers. The base container does not include PennyLane, so we need to use one of the two Pennylane containers: TensorFlow or PyTorch.

# %%
from braket.aws import AwsSession

region = AwsSession().region

# Base container does not have PennyLane, so we have to use the TF or PyTorch container
# Choose the container based on which one we need.
if interface == "autograd" or interface == "tf":
    image_uri = retrieve_image(Framework.PL_TENSORFLOW, region)
elif interface == "torch":
    image_uri = retrieve_image(Framework.PL_PYTORCH, region)

# %% [markdown]
# ## Algorithm script
#
# The complete algorithm script for solving the Max-Cut problem with QAOA is [here](qaoa_source/qaoa_algorithm_script.py).

# %% [markdown]
# ## Submitting a Braket Job
#
# We have now finished preparing the input data, algorithm script, hyperparameters and other configurations. It's time to submit our Braket Job!
#
# We specify the following arguments to create a Braket Job:
#
# - <code>device</code>: The arn of the Braket simulator or QPU we want to use. It will be stored as an environment variable for the algorithm script.
# - <code>source_module</code>: The path to a file or a python module that contains your algorithm script. It will be uploaded to the container for Braket Job execution.
# - <code>job_name</code>: A unique string to identify the job. It appears in the Braket Job console and in the job arn.
# - <code>image_uri</code>: The path to a Docker container image.
# - <code>entry point</code>: The path relative to the source_module. It points to the piece of code to be executed when the Braket Job starts.
# - <code>copy_checkpoints_from_job</code>: A string that specifies the job arn whose checkpoint you want to use in the current job. If `None` (default value), no checkpoints will be copied to the current job.
# - <code>hyperparameters</code>: The Python dictionary containing the hyperparameter names and values (as strings).
# - <code>input_data</code>: A dictionary that maps channel names to either a file location in the local environment or a path to S3. We can also specify only a file location, in which case the channel name is treated as "input".
# - <code>wait_until_complete</code>: If true, the function call will wait until the Braket Job is completedd, and will additionally print logs to the local console. Otherwise, it will run asynchronously.

# %%
# %%time 
# This cell should take 7 minutes

job = AwsQuantumJob.create(
    device=device,
    source_module="qaoa",
    # Any unique name works. Note 50-character limit in job name
    # (comment out to use default naming)
    job_name="qaoa-job-" + interface + "-" + str(int(time.time())),
    image_uri=image_uri,
    # Relative to the current location
    entry_point="qaoa_source.qaoa_algorithm_script",
    copy_checkpoints_from_job=None,
    # general parameters
    hyperparameters=hyperparameters,
    input_data={"input-graph": input_file_path},
    # Comment out the following line if you want to run the job
    # silently and asynchronously
    wait_until_complete=True,
)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/Documents/GitHub/amazon-braket-sdk-python-staging/src/braket/jobs/quantum_job_creation.py in _validate_entry_point(source_module_path, entry_point)
#     288         module = importlib.util.find_spec(importable, source_module_path.stem)
# --> 289         assert module is not None
#     290     # if entry point is nested (ie contains '.'), parent modules are imported
#
# AssertionError:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Documents/GitHub/amazon-braket-sdk-python-staging/src/braket/aws/aws_quantum_job.py in create(cls, device, source_module, entry_point, image_uri, job_name, code_location, role_arn, wait_until_complete, hyperparameters, metric_definitions, input_data, instance_config, stopping_condition, output_data_config, copy_checkpoints_from_job, checkpoint_config, aws_session)
#     162         aws_session = aws_session or AwsSession()
#     163
# --> 164         create_job_kwargs = prepare_quantum_job(
#     165             device=device,
#     166             source_module=source_module,
#
# ~/Documents/GitHub/amazon-braket-sdk-python-staging/src/braket/jobs/quantum_job_creation.py in prepare_quantum_job(device, source_module, entry_point, image_uri, job_name, code_location, role_arn, hyperparameters, input_data, instance_config, stopping_condition, output_data_config, copy_checkpoints_from_job, checkpoint_config, aws_session)
#     156     else:
#     157         # if entry point is None, it will be set to default here
# --> 158         entry_point = _process_local_source_module(
#     159             source_module, entry_point, aws_session, code_location
#     160         )
#
# ~/Documents/GitHub/amazon-braket-sdk-python-staging/src/braket/jobs/quantum_job_creation.py in _process_local_source_module(source_module, entry_point, aws_session, code_location)
#     269
#     270     entry_point = entry_point or abs_path_source_module.stem
# --> 271     _validate_entry_point(abs_path_source_module, entry_point)
#     272     _tar_and_upload_to_code_location(abs_path_source_module, aws_session, code_location)
#     273     return entry_point
#
# ~/Documents/GitHub/amazon-braket-sdk-python-staging/src/braket/jobs/quantum_job_creation.py in _validate_entry_point(source_module_path, entry_point)
#     290     # if entry point is nested (ie contains '.'), parent modules are imported
#     291     except (ModuleNotFoundError, AssertionError):
# --> 292         raise ValueError(f"Entry point module was not found: {importable}")
#     293     finally:
#     294         sys.path.pop()
#
# ValueError: Entry point module was not found: qaoa_source.qaoa_algorithm_script

# %% [markdown]
# ## View results

# %% [markdown]
# After the job is completed, we can view the result and the metric we defined in the algorithm script.

# %%
print(job.result())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rz/xm9j72zs2kl456qp244g49640000gs/T/ipykernel_34082/641729320.py in <module>
# ----> 1 print(job.result())
#
# NameError: name 'job' is not defined

# %%
# May need to wait a bit before metrics show up
# If metrics aren't there, run a bit later
print(job.metrics())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rz/xm9j72zs2kl456qp244g49640000gs/T/ipykernel_19285/2030290005.py in <module>
#       1 # May need to wait a bit before metrics show up
#       2 # If metrics aren't there, run a bit later
# ----> 3 print(job.metrics())
#
# NameError: name 'job' is not defined

# %%
# A demonstration of plotting the metrics
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import MaxNLocator

df = pd.DataFrame(job.metrics())

ax = plt.figure().gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
figure = df.plot(x="iteration_number", y="Cost", ax=ax)

# %% [markdown]
# ## Checkpoints

# %% [markdown]
# What if a job terminated early for an unforeseen reason, and we would like to continue training? In this case, we can create a new job, and load its training progress from a *checkpoint*. During training, the algorithm script contains this code:

# %%
# %%script echo "Code in the algorithm script for saving a checkpoint"
#
# for iteration in range(start_iteration, num_iterations):
#     # Training code omitted ...
#     # ...
#     save_job_checkpoint(
#         checkpoint_data={
#             "iteration": iteration + 1,
#             "params": np_params.tolist(),
#             "cost_before": cost_before,
#         },
#         checkpoint_file_suffix="checkpoint-1",
#     )
# Out:
# Code in the algorithm script for saving a checkpoint

# %% [markdown]
# This code creates and overwrites a checkpoint file `<jobname>-checkpoint-1.json` in your Job artifacts under a subfolder checkpoints. To load the checkpoint, at the start of training the algorithm script contains this code:

# %%
# %%script echo "Code in the algorithm script for loading a checkpoint"
#
# if "copy_checkpoints_from_job" in hyperparams:
#     copy_checkpoints_from_job = hyperparams["copy_checkpoints_from_job"].split("/", 2)[-1]
#
# if copy_checkpoints_from_job:
#     checkpoint_1 = load_job_checkpoint(
#         copy_checkpoints_from_job,
#         checkpoint_file_suffix="checkpoint-1",
#     )
#     start_iteration = checkpoint_1["iteration"]
#     params = interface.initialize_params(np.array(checkpoint_1["params"]))
#     print("Checkpoint loaded")
# Out:
# Code in the algorithm script for loading a checkpoint

# %% [markdown]
# This starts off the algorithm from the iteration and the parameters specified in the checkpoint file.

# %% [markdown]
# Let us see loading a checkpoint in action. We create a new job using the checkpoint from our existing job, this time training for another 2 iterations:

# %%
new_hyperparameters = dict(hyperparameters)
# Increase number of iterations by 2
new_hyperparameters["num_iterations"] = str(int(hyperparameters["num_iterations"]) + 2)
# Also add previous job arn in new hyperparameters
new_hyperparameters["copy_checkpoints_from_job"] = job.arn

start_time = time.time()

continued_job = AwsQuantumJob.create(
    device_arn=device_arn,
    source_module="qaoa_source",
    job_name="JobTestContd-" + interface + "-" + str(int(time.time())),
    image_uri=image_uri,
    entry_point="qaoa_source.qaoa_algorithm_script",
    # We specify the previous job arn to copy checkpoints from
    copy_checkpoints_from_job=job.arn,
    hyperparameters=new_hyperparameters,
    input_data={"input-graph": input_file_path},
    wait_until_complete=True,
)

end_time = time.time()
# Out:
# Initializing Braket Job: arn:aws:braket:<region>:<account-id>:job/<job-name>
# .................................................
# 2021-11-05 06:24:45.795494: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-11-05 06:24:45.802957: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-11-05 06:24:45.979163: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-11-05 06:24:50,333 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-11-05 06:24:50,333 sagemaker-training-toolkit INFO     Failed to parse hyperparameter copy_checkpoints_from_job value arn:aws:braket:<region>:<account-id>:job/<job-name> to Json.
# Returning the value itself
# 2021-11-05 06:24:50,334 sagemaker-training-toolkit INFO     Failed to parse hyperparameter interface value autograd to Json.
# Returning the value itself
# 2021-11-05 06:24:50,340 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-11-05 06:24:50,356 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-11-05 06:24:50,357 sagemaker-training-toolkit INFO     Failed to parse hyperparameter copy_checkpoints_from_job value arn:aws:braket:<region>:<account-id>:job/<job-name> to Json.
# Returning the value itself
# 2021-11-05 06:24:50,357 sagemaker-training-toolkit INFO     Failed to parse hyperparameter interface value autograd to Json.
# Returning the value itself
# 2021-11-05 06:24:50,397 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-11-05 06:24:50,397 sagemaker-training-toolkit INFO     Failed to parse hyperparameter copy_checkpoints_from_job value arn:aws:braket:<region>:<account-id>:job/<job-name> to Json.
# Returning the value itself
# 2021-11-05 06:24:50,398 sagemaker-training-toolkit INFO     Failed to parse hyperparameter interface value autograd to Json.
# Returning the value itself
# 2021-11-05 06:24:50,413 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-11-05 06:24:50,414 sagemaker-training-toolkit INFO     Failed to parse hyperparameter copy_checkpoints_from_job value arn:aws:braket:<region>:<account-id>:job/<job-name> to Json.
# Returning the value itself
# 2021-11-05 06:24:50,414 sagemaker-training-toolkit INFO     Failed to parse hyperparameter interface value autograd to Json.
# Returning the value itself
# 2021-11-05 06:24:50,423 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "input-graph": "/opt/ml/input/data/input-graph"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "p": 2,
#         "seed": 1967,
#         "num_iterations": 7,
#         "copy_checkpoints_from_job": "arn:aws:braket:<region>:<account-id>:job/<job-name>",
#         "interface": "autograd",
#         "shots": 1000,
#         "max_parallel": 10,
#         "stepsize": 0.1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "input-graph": {
#             "ContentType": "application/octet-stream",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "BraketJob-<account-id>-<job-name>",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "braket_container",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "braket_container.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"copy_checkpoints_from_job":"arn:aws:braket:<region>:<account-id>:job/<job-name>","interface":"autograd","max_parallel":10,"num_iterations":7,"p":2,"seed":1967,"shots":1000,"stepsize":0.1}
# SM_USER_ENTRY_POINT=braket_container.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"input-graph":{"ContentType":"application/octet-stream","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["input-graph"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=braket_container
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"input-graph":"/opt/ml/input/data/input-graph"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"copy_checkpoints_from_job":"arn:aws:braket:<region>:<account-id>:job/<job-name>","interface":"autograd","max_parallel":10,"num_iterations":7,"p":2,"seed":1967,"shots":1000,"stepsize":0.1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"input-graph":{"ContentType":"application/octet-stream","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"BraketJob-<account-id>-<job-name>","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"braket_container","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"braket_container.py"}
# SM_USER_ARGS=["--copy_checkpoints_from_job","arn:aws:braket:<region>:<account-id>:job/<job-name>","--interface","autograd","--max_parallel","10","--num_iterations","7","-p","2","--seed","1967","--shots","1000","--stepsize","0.1"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_INPUT-GRAPH=/opt/ml/input/data/input-graph
# SM_HP_P=2
# SM_HP_SEED=1967
# SM_HP_NUM_ITERATIONS=7
# SM_HP_COPY_CHECKPOINTS_FROM_JOB=arn:aws:braket:<region>:<account-id>:job/<job-name>
# SM_HP_INTERFACE=autograd
# SM_HP_SHOTS=1000
# SM_HP_MAX_PARALLEL=10
# SM_HP_STEPSIZE=0.1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.7 braket_container.py --copy_checkpoints_from_job arn:aws:braket:<region>:<account-id>:job/<job-name> --interface autograd --max_parallel 10 --num_iterations 7 -p 2 --seed 1967 --shots 1000 --stepsize 0.1
#
#
# Boto3 Version:  1.18.33
# Beginning Setup
# Getting setup script from  s3://braket-external-assets-preview-us-west-2/HybridJobsAccess/scripts/setup-container.sh
# Completed 50.5 KiB/50.5 KiB (69.8 KiB/s) with 1 file(s) remaining#015download: s3://braket-external-assets-preview-us-west-2/HybridJobsAccess/libraries/amazon-braket-schemas-python.tar.gz to ../../braket/additional_lib/original/amazon-braket-schemas-python.tar.gz
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.coveragerc
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.github/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.github/ISSUE_TEMPLATE/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.github/ISSUE_TEMPLATE/bug_report.md
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.github/ISSUE_TEMPLATE/config.yml
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.github/ISSUE_TEMPLATE/documentation_request.md
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.github/ISSUE_TEMPLATE/feature_request.md
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.github/pull_request_template.md
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.github/workflows/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.github/workflows/dependent-tests.yml
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.github/workflows/publish-to-pypi.yml
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.github/workflows/python-package.yml
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.github/workflows/stale_issue.yml
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.gitignore
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.pre-commit-config.yaml
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/.readthedocs.yml
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/CHANGELOG.md
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/CODEOWNERS
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/CODE_OF_CONDUCT.md
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/CONTRIBUTING.md
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/LICENSE
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/NOTICE
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/README.md
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/bin/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/bin/apply-header.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/doc/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/doc/Makefile
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/doc/conf.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/doc/index.rst
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/doc/requirements.txt
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/pyproject.toml
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/setup.cfg
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/setup.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/_schemas/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/_schemas/__init__.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/_schemas/_version.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/__init__.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/device_action_properties.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/device_capabilities.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/device_connectivity.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/device_execution_window.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/device_service_properties_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/dwave/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/dwave/__init__.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/dwave/dwave_2000Q_device_level_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/dwave/dwave_2000Q_device_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/dwave/dwave_advantage_device_level_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/dwave/dwave_advantage_device_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/dwave/dwave_device_capabilities_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/dwave/dwave_device_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/dwave/dwave_provider_level_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/dwave/dwave_provider_properties_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/gate_model_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/gate_model_qpu_paradigm_properties_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/ionq/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/ionq/__init__.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/ionq/ionq_device_capabilities_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/ionq/ionq_device_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/ionq/ionq_provider_properties_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/jaqcd_device_action_properties.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/rigetti/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/rigetti/__init__.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/rigetti/rigetti_device_capabilities_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/rigetti/rigetti_device_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/rigetti/rigetti_provider_properties_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/simulators/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/simulators/__init__.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/simulators/gate_model_simulator_device_capabilities_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/simulators/gate_model_simulator_device_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/device_schema/simulators/gate_model_simulator_paradigm_properties_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/ir/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/ir/annealing/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/ir/annealing/__init__.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/ir/annealing/problem_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/ir/jaqcd/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/ir/jaqcd/__init__.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/ir/jaqcd/instructions.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/ir/jaqcd/program_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/ir/jaqcd/results.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/ir/jaqcd/shared_models.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/jobs_data/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/jobs_data/__init__.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/jobs_data/persisted_job_data_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/schema_common/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/schema_common/__init__.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/schema_common/schema_base.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/schema_common/schema_header.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/task_result/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/task_result/__init__.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/task_result/additional_metadata.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/task_result/annealing_task_result_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/task_result/dwave_metadata_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/task_result/gate_model_task_result_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/task_result/rigetti_metadata_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/task_result/simulator_metadata_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/src/braket/task_result/task_metadata_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/dwave/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/dwave/test_dwave_2000Q_device_level_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/dwave/test_dwave_advantage_device_level_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/dwave/test_dwave_device_capabilities_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/dwave/test_dwave_device_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/dwave/test_dwave_provider_level_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/dwave/test_dwave_provider_properties_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/ionq/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/ionq/test_ionq_device_capabilities_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/ionq/test_ionq_device_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/ionq/test_ionq_provider_properties_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/rigetti/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/rigetti/test_rigetti_device_capabilities_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/rigetti/test_rigetti_device_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/rigetti/test_rigetti_provider_properties_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/simulator/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/simulator/test_gate_model_simulator_device_capabilities_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/simulator/test_gate_model_simulator_device_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/simulator/test_gate_model_simulator_paradigm_properties_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/test_device_action_properties.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/test_device_capabilities.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/test_device_connectivity.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/test_device_execution_window.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/test_device_service_properties_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/test_gate_model_parameters_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/test_gate_model_qpu_paradigm_properties_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/device_schema/test_jaqcd_device_action_properties.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/annealing/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/annealing/test_problem_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_angle.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_common.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_damping_probability.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_double_control.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_double_target.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_multi_control.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_multi_state.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_multi_target.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_observable.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_optional_multi_target.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_probability.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_program_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_quantum_instructions.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_results.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_single_control.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_single_probability.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_single_target.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_triple_probability.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_two_dimensional_matrix.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/ir/jaqcd/test_two_dimensional_matrix_list.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/jobs_data/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/jobs_data/test_persisted_job_data_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/schema_common/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/schema_common/conftest.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/schema_common/test_schema_base.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/schema_common/test_schema_header.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/task_result/
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/task_result/conftest.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/task_result/test_additional_metadata.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/task_result/test_annealing_task_result_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/task_result/test_dwave_metadata_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/task_result/test_gate_model_task_result_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/task_result/test_rigetti_metadata_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/task_result/test_simulator_metadata_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/test/unit_tests/braket/task_result/test_task_metadata_v1.py
# aws-amazon-braket-schemas-python-staging-6ffc1f24d0886b62d721a8c99fe2366d1f62822e/tox.ini
# Processing /opt/braket/additional_lib/extracted/amazon-braket-schemas-python
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: pydantic in /usr/local/lib/python3.7/site-packages (from amazon-braket-schemas==1.4.1.dev0) (1.7)
# Building wheels for collected packages: amazon-braket-schemas
#   Building wheel for amazon-braket-schemas (PEP 517): started
#   Building wheel for amazon-braket-schemas (PEP 517): finished with status 'done'
#   Created wheel for amazon-braket-schemas: filename=amazon_braket_schemas-1.4.1.dev0-py3-none-any.whl size=70390 sha256=3bd1e0a4fba1fb365bc80e1e9a0c6d75bde48481755a84e37687a11133fb61e0
#   Stored in directory: /root/.cache/pip/wheels/57/98/0b/db999598ccda095c5cdec9bef611264ed23d8f0e37f3871d6f
# Successfully built amazon-braket-schemas
# Installing collected packages: amazon-braket-schemas
#   Attempting uninstall: amazon-braket-schemas
#     Found existing installation: amazon-braket-schemas 1.2.2
#     Uninstalling amazon-braket-schemas-1.2.2:
#       Successfully uninstalled amazon-braket-schemas-1.2.2
# Successfully installed amazon-braket-schemas-1.4.1.dev0
# Completed 244.8 KiB/244.8 KiB (285.9 KiB/s) with 1 file(s) remaining#015download: s3://braket-external-assets-preview-us-west-2/HybridJobsAccess/libraries/amazon-braket-sdk-python.tar.gz to ../../braket/additional_lib/original/amazon-braket-sdk-python.tar.gz
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.coveragerc
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.github/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.github/ISSUE_TEMPLATE/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.github/ISSUE_TEMPLATE/bug_report.md
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.github/ISSUE_TEMPLATE/config.yml
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.github/ISSUE_TEMPLATE/documentation_request.md
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.github/ISSUE_TEMPLATE/feature_request.md
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.github/pull_request_template.md
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.github/workflows/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.github/workflows/dependent-tests.yml
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.github/workflows/publish-to-pypi.yml
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.github/workflows/python-package.yml
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.github/workflows/stale_issue.yml
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.gitignore
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.pre-commit-config.yaml
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/.readthedocs.yml
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/CHANGELOG.md
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/CODEOWNERS
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/CODE_OF_CONDUCT.md
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/CONTRIBUTING.md
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/LICENSE
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/MANIFEST.in
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/NOTICE
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/README.md
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/bin/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/bin/apply-header.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/doc/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/doc/Makefile
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/doc/conf.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/doc/examples-adv-circuits-algorithms.rst
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/doc/examples-braket-features.rst
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/doc/examples-getting-started.rst
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/doc/examples-hybrid-quantum.rst
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/doc/examples-ml-pennylane.rst
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/doc/examples-quantum-annealing-dwave.rst
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/doc/examples.rst
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/doc/getting-started.rst
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/doc/index.rst
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/doc/requirements.txt
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/examples/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/examples/bell.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/examples/bell_result_types.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/examples/debug_bell.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/examples/jobs/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/examples/jobs/algorithm_script.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/examples/jobs/orchestration.ipynb
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/examples/jobs/qaoa_orchestration.ipynb
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/examples/jobs/qaoa_source/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/examples/jobs/qaoa_source/qaoa_algorithm_script.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/examples/jobs/qaoa_source/qaoa_utils.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/examples/local_bell.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/examples/local_noise_simulation.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/pyproject.toml
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/setup.cfg
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/setup.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/_sdk/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/_sdk/__init__.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/_sdk/_version.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/annealing/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/annealing/__init__.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/annealing/problem.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/aws/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/aws/__init__.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/aws/aws_device.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/aws/aws_quantum_job.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/aws/aws_quantum_task.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/aws/aws_quantum_task_batch.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/aws/aws_session.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/__init__.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/angled_gate.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/ascii_circuit_diagram.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/circuit.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/circuit_diagram.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/circuit_helpers.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/compiler_directive.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/compiler_directives.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/gate.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/gates.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/instruction.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/moments.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/noise.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/noise_helpers.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/noises.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/observable.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/observables.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/operator.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/quantum_operator.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/quantum_operator_helpers.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/qubit.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/qubit_set.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/result_type.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/result_types.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/circuits/unitary_calculation.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/devices/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/devices/__init__.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/devices/device.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/devices/local_simulator.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/ipython_utils.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/__init__.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/config.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/data_persistence.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/image_uri_config/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/image_uri_config/base.json
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/image_uri_config/pl_pytorch.json
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/image_uri_config/pl_tensorflow.json
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/image_uris.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/local/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/local/__init__.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/local/local_job.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/local/local_job_container.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/local/local_job_container_setup.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/logs.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/metrics.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/metrics_data/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/metrics_data/__init__.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/metrics_data/cwl_insights_metrics_fetcher.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/metrics_data/cwl_metrics_fetcher.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/metrics_data/definitions.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/metrics_data/exceptions.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/metrics_data/log_metrics_parser.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/quantum_job.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/quantum_job_creation.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/jobs/serialization.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/tasks/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/tasks/__init__.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/tasks/annealing_quantum_task_result.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/tasks/gate_model_quantum_task_result.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/tasks/local_quantum_task.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/src/braket/tasks/quantum_task.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/integ_tests/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/integ_tests/conftest.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/integ_tests/gate_model_device_testing_utils.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/integ_tests/job_test_script.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/integ_tests/test_aws_session_s3.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/integ_tests/test_create_quantum_job.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/integ_tests/test_device_creation.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/integ_tests/test_local_braket_simulator.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/integ_tests/test_local_noise_simulator.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/integ_tests/test_simulator_quantum_task.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/integ_tests/test_tensor_network_simulator.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/annealing/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/annealing/test_problem.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/aws/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/aws/common_test_utils.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/aws/test_aws_device.py
# ...
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_compiler_directive.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_compiler_directives.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_gate.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_gates.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_instruction.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_moments.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_noise.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_noise_helpers.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_noises.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_observable.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_observables.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_quantum_operator.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_quantum_operator_helpers.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_qubit.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_qubit_set.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_result_type.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/circuits/test_result_types.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/devices/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/devices/test_local_simulator.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/jobs/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/jobs/local/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/jobs/local/test_local_job.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/jobs/local/test_local_job_container.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/jobs/local/test_local_job_container_setup.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/jobs/metrics_data/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/jobs/metrics_data/test_cwl_insights_metrics_fetcher.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/jobs/metrics_data/test_cwl_metrics_fetcher.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/jobs/metrics_data/test_log_metrics_parser.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/jobs/test_data_persistence.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/jobs/test_image_uris.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/jobs/test_metrics.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/jobs/test_quantum_job_creation.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/jobs/test_serialization.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/tasks/
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/tasks/test_annealing_quantum_task_result.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/tasks/test_gate_model_quantum_task_result.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/tasks/test_local_quantum_task.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/tasks/test_tasks_init.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/test/unit_tests/braket/test_ipython_utils.py
# aws-amazon-braket-sdk-python-staging-42af2046c2a5ed6fcbc2cd230337fa133c708d74/tox.ini
# Processing /opt/braket/additional_lib/extracted/amazon-braket-sdk-python
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: backoff in /usr/local/lib/python3.7/site-packages (from amazon-braket-sdk==1.9.6.dev0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/site-packages (from amazon-braket-sdk==1.9.6.dev0) (2.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/site-packages (from amazon-braket-sdk==1.9.6.dev0) (1.5.1)
# Collecting coverage==5.5
#   Downloading coverage-5.5-cp37-cp37m-manylinux2010_x86_64.whl (242 kB)
# Requirement already satisfied: boltons in /usr/local/lib/python3.7/site-packages (from amazon-braket-sdk==1.9.6.dev0) (21.0.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/site-packages (from amazon-braket-sdk==1.9.6.dev0) (1.18.33)
# Requirement already satisfied: amazon-braket-default-simulator in /usr/local/lib/python3.7/site-packages (from amazon-braket-sdk==1.9.6.dev0) (1.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from amazon-braket-sdk==1.9.6.dev0) (1.19.2)
# Requirement already satisfied: amazon-braket-schemas in /usr/local/lib/python3.7/site-packages (from amazon-braket-default-simulator->amazon-braket-sdk==1.9.6.dev0) (1.4.1.dev0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.7/site-packages (from amazon-braket-default-simulator->amazon-braket-sdk==1.9.6.dev0) (3.3.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.7/site-packages (from amazon-braket-schemas->amazon-braket-default-simulator->amazon-braket-sdk==1.9.6.dev0) (1.7)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/site-packages (from boto3->amazon-braket-sdk==1.9.6.dev0) (0.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/site-packages (from boto3->amazon-braket-sdk==1.9.6.dev0) (0.10.0)
# Requirement already satisfied: botocore<1.22.0,>=1.21.33 in /usr/local/lib/python3.7/site-packages (from boto3->amazon-braket-sdk==1.9.6.dev0) (1.21.33)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/site-packages (from botocore<1.22.0,>=1.21.33->boto3->amazon-braket-sdk==1.9.6.dev0) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/site-packages (from botocore<1.22.0,>=1.21.33->boto3->amazon-braket-sdk==1.9.6.dev0) (1.25.11)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.22.0,>=1.21.33->boto3->amazon-braket-sdk==1.9.6.dev0) (1.15.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.7/site-packages (from networkx->amazon-braket-sdk==1.9.6.dev0) (4.4.0)
# Building wheels for collected packages: amazon-braket-sdk
#   Building wheel for amazon-braket-sdk (PEP 517): started
#   Building wheel for amazon-braket-sdk (PEP 517): finished with status 'done'
#   Created wheel for amazon-braket-sdk: filename=amazon_braket_sdk-1.9.6.dev0-py3-none-any.whl size=152554 sha256=442af75580c25430877cd37cb6be00d225a7dbb2d7f2339808fb5db1460c179d
#   Stored in directory: /root/.cache/pip/wheels/9d/50/f5/3223a6160b514ea71c23d922bbf17833e4a90280c1787b0aaf
# Successfully built amazon-braket-sdk
# Installing collected packages: coverage, amazon-braket-sdk
#   Attempting uninstall: amazon-braket-sdk
#     Found existing installation: amazon-braket-sdk 1.7.1
#     Uninstalling amazon-braket-sdk-1.7.1:
#       Successfully uninstalled amazon-braket-sdk-1.7.1
# Successfully installed amazon-braket-sdk-1.9.6.dev0 coverage-5.5
# Completed 36.1 KiB/36.1 KiB (53.7 KiB/s) with 1 file(s) remaining#015download: s3://braket-external-assets-preview-us-west-2/HybridJobsAccess/models/braket-2019-09-01.normal.json to ../../braket/additional_lib/original/braket-2019-09-01.normal.json
# Running Code As Subprocess
# environ({'PATH': '/usr/local/openmpi/bin/:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'HOSTNAME': 'ip-10-0-231-81.ec2.internal', 'AMZN_BRAKET_JOB_TOKEN': 'arn:aws:braket:<region>:<account-id>:job/<job-name>', 'AMZN_BRAKET_SCRIPT_ENTRY_POINT': 'qaoa_source.qaoa_algorithm_script', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'AWS_REGION': '<region>', 'AMZN_BRAKET_CHECKPOINT_DIR': '/opt/jobs/checkpoints', 'AMZN_BRAKET_INPUT_DIR': '/opt/braket/input/data', 'AMZN_BRAKET_JOB_RESULTS_DIR': '/opt/braket/model', 'AMZN_BRAKET_JOB_RESULTS_S3_PATH': 'jobs/<job-name>/output/BraketJob-<account-id>-<job-name>/output', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/420d433c-22a1-4902-870c-dfe9a2103928', 'AMZN_BRAKET_SCRIPT_S3_URI': 's3://amazon-braket-your-bucket-name/jobs/<job-name>/script/source.tar.gz', 'AMZN_BRAKET_TASK_RESULTS_S3_URI': 's3://amazon-braket-your-bucket-name/jobs/<job-name>/tasks', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:<region>:273898505213:training-job/braketjob-<account-id>-<job-name>', 'AMZN_BRAKET_DEVICE_ARN': 'arn:aws:braket:::device/quantum-simulator/amazon/sv1', 'AMZN_BRAKET_HP_FILE': '/opt/braket/input/config/hyperparameters.json', 'AMZN_BRAKET_IMAGE_SETUP_SCRIPT': 's3://braket-external-assets-preview-us-west-2/HybridJobsAccess/scripts/setup-container.sh', 'AMZN_BRAKET_SCRIPT_COMPRESSION_TYPE': 'GZIP', 'TRAINING_JOB_NAME': 'BraketJob-<account-id>-<job-name>', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/27e45539-7916-4665-80b9-e0e1a9fa0789', 'AMZN_BRAKET_JOB_NAME': '<job-name>', 'AMZN_BRAKET_OUT_S3_BUCKET': 'amazon-braket-your-bucket-name', 'AWS_DEFAULT_REGION': '<region>', 'DMLC_INTERFACE': 'eth0', 'AMZN_BRAKET_IMAGE_ADDITIONAL_LIB': 's3://braket-external-assets-preview-us-west-2/HybridJobsAccess/libraries/combined.tar.gz', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/420d433c-22a1-4902-870c-dfe9a2103928', 'DEBIAN_FRONTEND': 'noninteractive', 'DEBCONF_NONINTERACTIVE_SEEN': 'true', 'SAGEMAKER_TRAINING_MODULE': 'sagemaker_tensorflow_container.training:main', 'KMP_AFFINITY': 'granularity=fine,compact,1,0', 'KMP_BLOCKTIME': '1', 'KMP_SETTINGS': '0', 'PYTHONDONTWRITEBYTECODE': '1', 'PYTHONUNBUFFERED': '1', 'PYTHONIOENCODING': 'UTF-8', 'LANG': 'C.UTF-8', 'LC_ALL': 'C.UTF-8', 'LD_LIBRARY_PATH': '/usr/local/openmpi/lib:', 'SAGEMAKER_PROGRAM': 'braket_container.py', 'HOME': '/root', 'SAGEMAKER_JOB_NAME': '', 'CURRENT_HOST': 'algo-1', 'SAGEMAKER_REGION': '<region>', 'TF2_BEHAVIOR': '1', 'S3_REGION': '<region>', 'TF_CPP_MIN_LOG_LEVEL': '1', 'S3_USE_HTTPS': '1', 'SM_HOSTS': '["algo-1"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"copy_checkpoints_from_job":"arn:aws:braket:<region>:<account-id>:job/<job-name>","interface":"autograd","max_parallel":10,"num_iterations":7,"p":2,"seed":1967,"shots":1000,"stepsize":0.1}', 'SM_USER_ENTRY_POINT': 'braket_container.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"input-graph":{"ContentType":"application/octet-stream","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["input-graph"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'braket_container', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_tensorflow_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '2', 'SM_NUM_GPUS': '0', 'SM_MODEL_DIR': '/opt/ml/model', 'SM_MODULE_DIR': '/opt/ml/code', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"input-graph":"/opt/ml/input/data/input-graph"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"copy_checkpoints_from_job":"arn:aws:braket:<region>:<account-id>:job/<job- ...
# {'p': '2', 'seed': '1967', 'num_iterations': '7', 'copy_checkpoints_from_job': 'arn:aws:braket:<region>:<account-id>:job/<job-name>', 'interface': 'autograd', 'shots': '1000', 'max_parallel': '10', 'stepsize': '0.1'}
# Checkpoint loaded
# Optimization start
# Cost at step 5: -4.697
# Metrics - timestamp=1636093541.9000573; Cost=-4.697; iteration_number=5;
# Completed iteration 6
# Time to complete iteration: 25.685705423355103 seconds
# Cost at step 6: -2.95
# Metrics - timestamp=1636093566.8675892; Cost=-2.95; iteration_number=6;
# Completed iteration 7
# Time to complete iteration: 24.963124752044678 seconds
# Metrics - timestamp=1636093569.5993972; Cost=-4.766; iteration_number=7;
# Cost at step 7: -4.766
# Code Run Finished
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# WARNING: You are using pip version 21.1.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/local/bin/python -m pip install --upgrade pip' command.
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# WARNING: You are using pip version 21.1.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/local/bin/python -m pip install --upgrade pip' command.
#
# 2021-11-05 06:26:09,887 sagemaker_tensorflow_container.training WARNING  Your model will NOT be servable with SageMaker TensorFlow Serving container. The model artifact was not saved in the TensorFlow SavedModel directory structure:
# https://www.tensorflow.org/guide/saved_model#structure_of_a_savedmodel_directory
# 2021-11-05 06:26:09,887 sagemaker-training-toolkit INFO     Reporting training SUCCESS

# %%
df = pd.DataFrame(continued_job.metrics())

ax = plt.figure().gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
figure = df.plot(x="iteration_number", y="Cost", ax=ax)

# %% [markdown]
# ## Summary
#
# In this tutorial, we set up a Max-Cut problem with a random graph using Pennylane. We saved the graph to a local file and provided it as input data to our Braket Job, along with the pre-built Pennylane container image. Variables that are required for the training process and the optimizer are passed as hyperparameters. The result is retrieved after the QAOA algorithm is completed. Lastly, we demonstrated how to use checkpoints to save and load training progress of a job.
